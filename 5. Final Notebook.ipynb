# %%
import numpy as np
import pandas as pd
import re
import requests
import json
import time

# %%
df = pd.read_csv("4. Final_Dataset.csv")
df.head(2)
# Out:
#    Index        ASIN Model Number Manufacturer Name Generic Name  \
# 0      6  B0DZDC247V    MW0Y3HN/A             Apple  MacBook Air
# 1     12  B0DZDC247V    MW0Y3HN/A             Apple  MacBook Air
#
#                                        Product Title  Price  Overall Rating  \
# 0  Apple 2025 MacBook Air (13-inch, Apple M4 chip...  89990             4.5
# 1  Apple 2025 MacBook Air (13-inch, Apple M4 chip...  89990             4.5
#
#    Rating Count  Review Count  ...  \
# 0            33            15  ...
# 1            33            15  ...
#
#                                  Product Description Verified Purchase  \
# 0  Colour: Midnight|Size: 16GB Unified Memory|Sty...              True
# 1  Colour: Starlight|Size: 16GB Unified Memory|St...             False
#
#                                          Review Text Helpful Votes  \
# 0                       Battery life is only 6 hours            35
# 1  I am planning to but this model but I am seein...            10
#
#                                  Cleaned Review Text  \
# 0                       battery life is only 6 hours
# 1  i am planning to but this model but i am seein...
#
#                                              llm_raw  \
# 0  Based on the given examples and rules, here's ...
# 1  Based on the review content, here's the output...
#
#                                           llm_parsed Sentiment  \
# 0  {'Sentiment': 'Negative', 'Aspect-PainPoint Pa...  Negative
# 1  {'Sentiment': 'Neutral', 'Aspect-PainPoint Pai...   Neutral
#
#                 Aspect-PainPoint Pairs Standardized Aspect-PainPoint Pairs
# 0      ['Battery - Short backup time']     ['Battery - Short backup time']
# 1  ['Processor - Low speed (0.01mhz)']    ['Processor - Slow performance']
#
# [2 rows x 27 columns]

# %% [markdown]
# ### Data Preprocessing

# %%
df.columns
# Out:
# Index(['Index', 'ASIN', 'Model Number', 'Manufacturer Name', 'Generic Name',
#        'Product Title', 'Price', 'Overall Rating', 'Rating Count',
#        'Review Count', 'Bought L Month', 'Product Link', 'Customer Say',
#        'Insight', 'Individual Rating', 'Review Title', 'Review Date',
#        'Product Description', 'Verified Purchase', 'Review Text',
#        'Helpful Votes', 'Cleaned Review Text', 'llm_raw', 'llm_parsed',
#        'Sentiment', 'Aspect-PainPoint Pairs',
#        'Standardized Aspect-PainPoint Pairs'],
#       dtype='object')

# %% [markdown]
# ## 🔄 Exploding Aspect-PainPoint Pairs into Individual Rows
#
# This block transforms the list-style `"Aspect-PainPoint Pairs"` and `"Standardized Aspect-PainPoint Pairs"` into **row-wise entries** — allowing easier downstream filtering, grouping, or labeling.

# %%
final_list = []
last_len = 0

def change_quotes(x):
    return x.replace('"', "'") if isinstance(x, str) else x

df['Aspect-PainPoint Pairs'] = df['Aspect-PainPoint Pairs'].apply(change_quotes)
df['Standardized Aspect-PainPoint Pairs'] = df['Standardized Aspect-PainPoint Pairs'].apply(change_quotes)

for idx, rows in df.iterrows():
    a1 = rows["Aspect-PainPoint Pairs"].strip('[').strip(']').split("',")
    a2 = rows["Standardized Aspect-PainPoint Pairs"].strip('[').strip(']').split("',")

    last_len = max(len(a1), len(a2))

    for first in range(last_len):
        x1 = a1[first].strip().strip("'") if first < len(a1) else None
        x2 = a2[first].strip().strip("'") if first < len(a2) else None

        final_list.append([
            rows['Index'], rows['ASIN'], rows['Model Number'], rows['Manufacturer Name'], rows['Generic Name'], 
            rows['Product Title'], rows['Price'], rows['Overall Rating'], rows['Rating Count'], rows['Review Count'], 
            rows['Bought L Month'], rows['Product Link'], rows['Customer Say'], rows['Insight'], rows['Individual Rating'], 
            rows['Review Title'], rows['Review Date'], rows['Product Description'], rows['Verified Purchase'], 
            rows['Review Text'], rows['Helpful Votes'], rows['Cleaned Review Text'], rows['llm_raw'], rows['llm_parsed'], 
            rows['Sentiment'], x1, x2
        ])

# %%
df1 = pd.DataFrame(data = final_list, columns=['Index', 'ASIN', 'Model Number', 'Manufacturer Name', 'Generic Name',
       'Product Title', 'Price', 'Overall Rating', 'Rating Count',
       'Review Count', 'Bought L Month', 'Product Link', 'Customer Say',
       'Insight', 'Individual Rating', 'Review Title', 'Review Date',
       'Product Description', 'Verified Purchase', 'Review Text',
       'Helpful Votes', 'Cleaned Review Text', 'llm_raw', 'llm_parsed',
       'Sentiment', 'Aspect-PainPoint Pairs',
       'Standardized Aspect-PainPoint Pairs'])

# %%
df1.head()
# Out:
#    Index        ASIN Model Number Manufacturer Name Generic Name  \
# 0      6  B0DZDC247V    MW0Y3HN/A             Apple  MacBook Air
# 1     12  B0DZDC247V    MW0Y3HN/A             Apple  MacBook Air
# 2     17  B0DP7BZ8FD       14IAH8            Lenovo       Laptop
# 3     17  B0DP7BZ8FD       14IAH8            Lenovo       Laptop
# 4     17  B0DP7BZ8FD       14IAH8            Lenovo       Laptop
#
#                                        Product Title  Price  Overall Rating  \
# 0  Apple 2025 MacBook Air (13-inch, Apple M4 chip...  89990             4.5
# 1  Apple 2025 MacBook Air (13-inch, Apple M4 chip...  89990             4.5
# 2  Lenovo IdeaPad Slim 3, Intel Core i5-12450H, 1...  47390             3.9
# 3  Lenovo IdeaPad Slim 3, Intel Core i5-12450H, 1...  47390             3.9
# 4  Lenovo IdeaPad Slim 3, Intel Core i5-12450H, 1...  47390             3.9
#
#    Rating Count  Review Count  ...  \
# 0            33            15  ...
# 1            33            15  ...
# 2           609           165  ...
# 3           609           165  ...
# 4           609           165  ...
#
#                                  Product Description Verified Purchase  \
# 0  Colour: Midnight|Size: 16GB Unified Memory|Sty...              True
# 1  Colour: Starlight|Size: 16GB Unified Memory|St...             False
# 2             Colour: 12th Gen i5 | 16GB | 512GB SSD              True
# 3             Colour: 12th Gen i5 | 16GB | 512GB SSD              True
# 4             Colour: 12th Gen i5 | 16GB | 512GB SSD              True
#
#                                          Review Text Helpful Votes  \
# 0                       Battery life is only 6 hours            35
# 1  I am planning to but this model but I am seein...            10
# 2  So 1st of all I got this laptop in 41000 durin...            99
# 3  So 1st of all I got this laptop in 41000 durin...            99
# 4  So 1st of all I got this laptop in 41000 durin...            99
#
#                                  Cleaned Review Text  \
# 0                       battery life is only 6 hours
# 1  i am planning to but this model but i am seein...
# 2  so 1st of all i got this laptop in 41000 durin...
# 3  so 1st of all i got this laptop in 41000 durin...
# 4  so 1st of all i got this laptop in 41000 durin...
#
#                                              llm_raw  \
# 0  Based on the given examples and rules, here's ...
# 1  Based on the review content, here's the output...
# 2  What a long review!\n\nHere's my analysis:\n\n...
# 3  What a long review!\n\nHere's my analysis:\n\n...
# 4  What a long review!\n\nHere's my analysis:\n\n...
#
#                                           llm_parsed Sentiment  \
# 0  {'Sentiment': 'Negative', 'Aspect-PainPoint Pa...  Negative
# 1  {'Sentiment': 'Neutral', 'Aspect-PainPoint Pai...   Neutral
# 2  {'Sentiment': 'Positive', 'Aspect-PainPoint Pa...  Positive
# 3  {'Sentiment': 'Positive', 'Aspect-PainPoint Pa...  Positive
# 4  {'Sentiment': 'Positive', 'Aspect-PainPoint Pa...  Positive
#
#                               Aspect-PainPoint Pairs  \
# 0                        Battery - Short backup time
# 1                    Processor - Low speed (0.01mhz)
# 2                   Display - Not OLED/WUXGA quality
# 3  Battery - Short backup time (2-6 hours dependi...
# 4                 Processor - Low gaming performance
#
#      Standardized Aspect-PainPoint Pairs
# 0            Battery - Short backup time
# 1           Processor - Slow performance
# 2         Display - Poor display quality
# 3         Battery - Limited battery life
# 4  Processor - Gaming performance issues
#
# [5 rows x 27 columns]

# %%
df1.shape
# Out:
# (3798, 27)

# %%
df1.isnull().sum()
# Out:
# Index                                     0
# ASIN                                      0
# Model Number                              0
# Manufacturer Name                         0
# Generic Name                             38
# Product Title                             0
# Price                                     0
# Overall Rating                            0
# Rating Count                              0
# Review Count                              0
# Bought L Month                         1260
# Product Link                              0
# Customer Say                            476
# Insight                                 476
# Individual Rating                         1
# Review Title                              0
# Review Date                               0
# Product Description                     644
# Verified Purchase                         0
# Review Text                               0
# Helpful Votes                             0
# Cleaned Review Text                       0
# llm_raw                                   0
# llm_parsed                                0
# Sentiment                                 3
# Aspect-PainPoint Pairs                    1
# Standardized Aspect-PainPoint Pairs      36
# dtype: int64

# %%
df1[
    (df1['Aspect-PainPoint Pairs'].isnull() | df1['Aspect-PainPoint Pairs'].isin(["None", ""]))
    &
    (df1['Standardized Aspect-PainPoint Pairs'].isnull() | df1['Standardized Aspect-PainPoint Pairs'].isin(["None", ""]))
]
# Out:
#       Index        ASIN         Model Number Manufacturer Name  \
# 5        18  B0DP7BZ8FD               14IAH8            Lenovo
# 233     289  B08N5W4NNB            MGN63HN/A             Apple
# 243     317  B08N5W4NNB            MGN63HN/A             Apple
# 347     426  B0F4R6H3NB             fd0577TU                HP
# 514     592  B0C4ZM63RP        Inspiron 3530              Dell
# 1264   1432  B0DRCTY5JH               15IGL7            Lenovo
# 1430   1568  B0F8WC83WT                HP 15                HP
# 1666   1860  B0DJCWZ5BT               245 G9                HP
# 1746   1943  B0C3RF3HT3          15-fd0006TU                HP
# 1868   2086  B0CY2LDT1S               14IMH9            Lenovo
# 2276   2449  B0D2LG3DRJ             99Y0Y6PA                HP
# 2515   2698  B0DCG8DMRR              A33FPPA                HP
# 2583   2761  B0CP2KRYLM           82R400ERIN            Lenovo
# 2600   2779  B0CP2KRYLM           82R400ERIN            Lenovo
# 2952   3129  B0CX8PHK2P               15IRX9            Lenovo
# 2964   3138  B0CRKXDX83  New Dell Gaming G15              Dell
# 3489   3542  B0CZ7DNGZH      ThinkBook 16 G6            Lenovo
# 3542   3602  B0DPT19FZD              255 G10                HP
# 3637   3702  B0DTYZ2CG8             fa2700TX                HP
#
#          Generic Name                                      Product Title  \
# 5              Laptop  Lenovo IdeaPad Slim 3, Intel Core i5-12450H, 1...
# 233            Laptop  Apple MacBook Air Laptop: Apple M1 chip, 13.3-...
# 243            Laptop  Apple MacBook Air Laptop: Apple M1 chip, 13.3-...
# 347            Laptop  HP 15, 13th Gen Intel Core i5-1335U (16GB DDR4...
# 514            Laptop  Dell Inspiron 3530 Thin & Light Laptop, 13th G...
# 1264           Laptop  Lenovo IdeaPad Slim 1 Intel® Celeron® N4020 15...
# 1430  BUSINESS LAPTOP  HP 15 (2025), Intel Core i3 13th Gen 1315U - (...
# 1666  BUSINESS LAPTOP  HP Laptop 245 G9 AMD Ryzen 3 3250U Dual Core -...
# 1746           Laptop  HP 15, 13th Gen Intel Core i3-1315U (8GB DDR4,...
# 1868           Laptop  Lenovo IdeaPad Pro 5, Intel Core Ultra 9 185H,...
# 2276           Laptop  HP Victus, 13th Gen Intel Core i5-13420H, 4GB ...
# 2515           Laptop  HP 15, 12th Gen Intel Core i3-1215U Laptop (8G...
# 2583           Laptop  Lenovo IdeaPad Slim 1 AMD Ryzen 5 5500U 15.6" ...
# 2600           Laptop  Lenovo IdeaPad Slim 1 AMD Ryzen 5 5500U 15.6" ...
# 2952           Laptop  Lenovo LOQ Intel Core i7-13650HX 15.6" (39.6cm...
# 2964           Laptop  Dell G-series-15-5530-laptop - 15.6-inch FHD, ...
# 3489           Laptop  Lenovo Thinkbook 16 G6 AMD Ryzen 5 16" Wuxga I...
# 3542           Laptop  HP 255 G10 AMD Ryzen 3 Quad Core 7320U - (8 GB...
# 3637           Laptop  HP Victus, 13th Gen Intel Core i5-13420H, 6GB ...
#
#        Price  Overall Rating  Rating Count  Review Count  ...  \
# 5      47390             3.9           609           165  ...
# 233    54990             4.6          7004          1500  ...
# 243    54990             4.6          7004          1500  ...
# 347    51990             3.8            26            18  ...
# 514    33990             4.0           171            48  ...
# 1264   25500             3.6           320            74  ...
# 1430   33490             4.0            19            12  ...
# 1666   26490             3.1            23            13  ...
# 1746   35690             3.8           235            90  ...
# 1868  108940             4.2           141            65  ...
# 2276   69900             4.0           117            45  ...
# 2515   33900             4.0          1441           331  ...
# 2583   39990             4.0           360            89  ...
# 2600   39990             4.0           360            89  ...
# 2952  108990             4.1           238            76  ...
# 2964   74990             4.0          1164           387  ...
# 3489   47990             4.1           137            58  ...
# 3542   26874             2.5            23            19  ...
# 3637   58990             3.8           225            82  ...
#
#                                     Product Description Verified Purchase  \
# 5                         Colour: i5-12th | Office 2024              True
# 233                     Colour: Space Grey|Size: 256 GB              True
# 243                         Colour: Silver|Size: 256 GB              True
# 347                                         Size: 512GB             False
# 514                                       Colour: Black              True
# 1264                              Size: 4GB | 256GB SSD              True
# 1430                                                NaN             False
# 1666                                                NaN              True
# 1746                                      Size: 8GB Ram              True
# 1868                            Colour: 14" | 2.8K OLED              True
# 2276                                Colour: Mica Silver              True
# 2515                             Colour: Natural Silver              True
# 2583                                 Colour: Cloud Grey              True
# 2600                              Colour: Ryzen 5 7520U              True
# 2952  Style Name: Intel Core i5-13450HX | 16GB RAM |...             False
# 2964  Style Name: Gaming Laptop|Size: 8GB & 512GB SS...              True
# 3489  Style Name: R5 7530U | 16 Inch | 16GB RAM | 51...              True
# 3542                                                NaN              True
# 3637                               Style Name: 1 TB SSD              True
#
#                                             Review Text Helpful Votes  \
# 5     This Laptop is great, No issues. but I want to...             1
# 233   This is the review i am writing after using th...             5
# 243   I got my product delivered earlier this week. ...            95
# 347   Product design is good. Performance is stable....             0
# 514   worst and no proper communication for refund t...             6
# 1264  The lappy is performing extremely slow even on...             3
# 1430  good enough value for simple tasks, it doesn't...             0
# 1666  Product comes without in built MS office. It a...             1
# 1746    It got damaged with in one year . Worst quality             0
# 1868  Received 5 months used laptop. Ab aap dekh lo ...             4
# 2276  Battery is draining too fast like 1% per minut...             1
# 2515  Battery stopped charging in less than 6 months...             0
# 2583  Overall product is good but some issues face a...             0
# 2600  Its been 2 months since i brought the laptop a...             0
# 2952  Worst product don't buy this . In two days onl...             0
# 2964  I bought Dell G15 recently and I will tell you...            49
# 3489  Display- Good RAM - 16GB | 64GB ROM- 512GB | 1...             4
# 3542            Good but adobe photoshop is not working             0
# 3637  I've been using the HP Victus with the 13th Ge...            13
#
#                                     Cleaned Review Text  \
# 5     this laptop is great, no issues. but i want to...
# 233   this is the review i am writing after using th...
# 243   i got my product delivered earlier this week. ...
# 347   product design is good. performance is stable....
# 514   worst and no proper communication for refund t...
# 1264  the lappy is performing extremely slow even on...
# 1430  good enough value for simple tasks, it doesnt ...
# 1666  product comes without in built ms office. it a...
# 1746    it got damaged with in one year . worst quality
# 1868  received 5 months used laptop. ab aap dekh lo ...
# 2276  battery is draining too fast like 1 per minute...
# 2515  battery stopped charging in less than 6 months...
# 2583  overall product is good but some issues face a...
# 2600  its been 2 months since i brought the laptop a...
# 2952  worst product dont buy this . in two days only...
# 2964  i bought dell g15 recently and i will tell you...
# 3489  display- good ram - 16gb 64gb rom- 512gb 1tb b...
# 3542            good but adobe photoshop is not working
# 3637  ive been using the hp victus with the 13th gen...
#
#                                                 llm_raw  \
# 5     A new challenge!\n\nAfter analyzing the review...
# 233   ### Analyzing the review...\n\n{\n  "Sentiment...
# 243   A new review to analyze!\n\nAfter processing t...
# 347   The review says: """product design is good. pe...
# 514   Based on the provided examples, I will extract...
# 1264  Here's the output for the given review:\n\n{\n...
# 1430  A new review to analyze!\n\nReview: """good en...
# 1666  The review is:\n\n"product comes without in bu...
# 1746  Based on the provided information and examples...
# 1868  I can help with that!\n\nReview: """received 5...
# 2276  Based on the given review, I can extract the f...
# 2515  Output:\n{\n  "Sentiment": "Negative",\n  "Asp...
# 2583  What a great set of examples!\n\nNow, let's di...
# 2600  Based on the provided review, I would extract ...
# 2952  Here is the output for the given review:\n\n{\...
# 2964  Based on the review content, here's the extrac...
# 3489  What a fascinating challenge!\n\nAfter analyzi...
# 3542  Based on the input review """good but adobe ph...
# 3637  Here's the output:\n\n{\n  "Sentiment": "Posit...
#
#                                              llm_parsed Sentiment  \
# 5     {'Sentiment': 'Positive', 'Aspect-PainPoint Pa...  Positive
# 233   {'Sentiment': 'Positive', 'Aspect-PainPoint Pa...  Positive
# 243   {'Sentiment': 'Positive', 'Aspect-PainPoint Pa...  Positive
# 347   {'Sentiment': 'Positive', 'Aspect-PainPoint Pa...  Positive
# 514   {'Sentiment': 'Negative', 'Aspect-PainPoint Pa...  Negative
# 1264  {'Sentiment': 'Negative', 'Aspect-PainPoint Pa...  Negative
# 1430  {'Sentiment': 'Positive', 'Aspect-PainPoint Pa...  Positive
# 1666  {'Sentiment': 'Negative', 'Aspect-PainPoint Pa...  Negative
# 1746  {'Sentiment': 'Negative', 'Aspect-PainPoint Pa...  Negative
# 1868  {'Sentiment': 'Negative', 'Aspect-PainPoint Pa...  Negative
# 2276  {'Sentiment': 'Negative', 'Aspect-PainPoint Pa...  Negative
# 2515  {'Sentiment': 'Negative', 'Aspect-PainPoint Pa...  Negative
# 2583  {'Sentiment': 'Positive', 'Aspect-PainPoint Pa...  Positive
# 2600  {'Sentiment': 'Negative', 'Aspect-PainPoint Pa...  Negative
# 2952  {'Sentiment': 'Negative', 'Aspect-PainPoint Pa...  Negative
# 2964  {'Sentiment': 'Positive', 'Aspect-PainPoint Pa...  Positive
# 3489  {'Sentiment': 'Positive', 'Aspect-PainPoint Pa...  Positive
# 3542  {'Sentiment': 'Neutral', 'Aspect-PainPoint Pai...   Neutral
# 3637  {'Sentiment': 'Positive', 'Aspect-PainPoint Pa...  Positive
#
#       Aspect-PainPoint Pairs Standardized Aspect-PainPoint Pairs
# 5                       None                                None
# 233                     None                                None
# 243                     None                                None
# 347                     None                                None
# 514                     None                                None
# 1264                    None                                None
# 1430                    None                                None
# 1666                    None                                None
# 1746                    None                                None
# 1868                    None                                None
# 2276                    None                                None
# 2515                    None                                None
# 2583                    None                                None
# 2600                    None                                None
# 2952                    None                                None
# 2964                    None                                None
# 3489                    None                                None
# 3542                    None                                None
# 3637                    None                                None
#
# [19 rows x 27 columns]

# %%
x = df1[
    (df1['Aspect-PainPoint Pairs'].isnull() | df1['Aspect-PainPoint Pairs'].isin(["None", ""]))
    &
    (df1['Standardized Aspect-PainPoint Pairs'].isnull() | df1['Standardized Aspect-PainPoint Pairs'].isin(["None", ""]))
].index
x
# Out:
# Index([   5,  233,  243,  347,  514, 1264, 1430, 1666, 1746, 1868, 2276, 2515,
#        2583, 2600, 2952, 2964, 3489, 3542, 3637],
#       dtype='int64')

# %%
df1.shape
# Out:
# (3798, 27)

# %%
df1.drop(x, axis=0, inplace=True)

# %%
df1.shape
# Out:
# (3779, 27)

# %%
df1[
    (df1['Aspect-PainPoint Pairs'].isnull() | df1['Aspect-PainPoint Pairs'].isin(["None", ""]))
    &
    (df1['Standardized Aspect-PainPoint Pairs'].isnull() | df1['Standardized Aspect-PainPoint Pairs'].isin(["None", ""]))
]
# Out:
# Empty DataFrame
# Columns: [Index, ASIN, Model Number, Manufacturer Name, Generic Name, Product Title, Price, Overall Rating, Rating Count, Review Count, Bought L Month, Product Link, Customer Say, Insight, Individual Rating, Review Title, Review Date, Product Description, Verified Purchase, Review Text, Helpful Votes, Cleaned Review Text, llm_raw, llm_parsed, Sentiment, Aspect-PainPoint Pairs, Standardized Aspect-PainPoint Pairs]
# Index: []
#
# [0 rows x 27 columns]

# %%
df1.isnull().sum()
# Out:
# Index                                     0
# ASIN                                      0
# Model Number                              0
# Manufacturer Name                         0
# Generic Name                             38
# Product Title                             0
# Price                                     0
# Overall Rating                            0
# Rating Count                              0
# Review Count                              0
# Bought L Month                         1251
# Product Link                              0
# Customer Say                            475
# Insight                                 475
# Individual Rating                         1
# Review Title                              0
# Review Date                               0
# Product Description                     641
# Verified Purchase                         0
# Review Text                               0
# Helpful Votes                             0
# Cleaned Review Text                       0
# llm_raw                                   0
# llm_parsed                                0
# Sentiment                                 3
# Aspect-PainPoint Pairs                    1
# Standardized Aspect-PainPoint Pairs      27
# dtype: int64

# %%
df1[(df1['Aspect-PainPoint Pairs'].isnull()) | (df1['Aspect-PainPoint Pairs'].isin(["None", "", "none"]))]
# Out:
#      Index        ASIN Model Number Manufacturer Name Generic Name  \
# 986   1143  B0D872NJSM       15IAU7            Lenovo       Laptop
#
#                                          Product Title  Price  Overall Rating  \
# 986  Lenovo IdeaPad 3 12th Gen Intel Core i3-1215U ...  34539             4.1
#
#      Rating Count  Review Count  ...                 Product Description  \
# 986          1145           208  ...  Style Name: Intel Core i3-11th Gen
#
#     Verified Purchase                                        Review Text  \
# 986              True  The laptop is excellent with respect to perfor...
#
#     Helpful Votes                                Cleaned Review Text  \
# 986             5  the laptop is excellent with respect to perfor...
#
#                                                llm_raw  \
# 986  Based on the review content, here's the output...
#
#                                             llm_parsed Sentiment  \
# 986  {'Sentiment': 'Positive', 'Aspect-PainPoint Pa...  Positive
#
#      Aspect-PainPoint Pairs                Standardized Aspect-PainPoint Pairs
# 986                    None  Display - May not be suitable for those specif...
#
# [1 rows x 27 columns]

# %% [markdown]
# > **Note:** `index != False` is intentionally set to retain the DataFrame index as a column.
# > This index acts as a **unique primary key** to help trace each review across different transformations and outputs.

# %%
# df1.to_csv('5. Analyze_dataset1.csv')

# %%
df1 = pd.read_csv('5. Analyze_dataset1.csv')

# %%
df1.columns
# Out:
# Index(['Primary Key', 'Index', 'ASIN', 'Model Number', 'Manufacturer Name',
#        'Generic Name', 'Product Title', 'Price', 'Overall Rating',
#        'Rating Count', 'Review Count', 'Bought L Month', 'Product Link',
#        'Customer Say', 'Insight', 'Individual Rating', 'Review Title',
#        'Review Date', 'Product Description', 'Verified Purchase',
#        'Review Text', 'Helpful Votes', 'Cleaned Review Text', 'llm_raw',
#        'llm_parsed', 'Sentiment', 'Aspect-PainPoint Pairs',
#        'Standardized Aspect-PainPoint Pairs'],
#       dtype='object')

# %%
crop_df = df1[['Primary Key', 'Aspect-PainPoint Pairs', 'Standardized Aspect-PainPoint Pairs']]
crop_df.head(2)
# Out:
#    Primary Key           Aspect-PainPoint Pairs  \
# 0            0      Battery - Short backup time
# 1            1  Processor - Low speed (0.01mhz)
#
#   Standardized Aspect-PainPoint Pairs
# 0         Battery - Short backup time
# 1        Processor - Slow performance

# %%
# crop_df.to_csv('5_1. review_df.csv', index=False)

# %% [markdown]
# > 📌 To ensure the accuracy of the standardized dataset, I exported it as **`review_df.csv`** and manually verified the transformations using **Power Query Editor**.
# > After confirming the data consistency and correctness, I saved the final version as **`Main Dataset.xlsx`** for further analysis and reporting.

# %%
data = pd.read_excel("5_2. Main Dataset.xlsx")
data.head(2)
# Out:
#    Primary Key        Original Aspect-PainPoint         Standardized Category  \
# 0            0      Battery - Short backup time   Battery - Short Backup Time
# 1            1  Processor - Low speed (0.01mhz)  Processor - Slow Performance
#
#   Standardized Aspect Standardized Pain Point
# 0             Battery       Short Backup Time
# 1           Processor        Slow Performance

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3778 entries, 0 to 3777
# Data columns (total 5 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Primary Key                3778 non-null   int64
#  1   Original Aspect-PainPoint  3778 non-null   object
#  2   Standardized Category      3778 non-null   object
#  3   Standardized Aspect        3778 non-null   object
#  4   Standardized Pain Point    3775 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 147.7+ KB

# %%
len(data)
# Out:
# 3778

# %%
df1.columns
# Out:
# Index(['Primary Key', 'Index', 'ASIN', 'Model Number', 'Manufacturer Name',
#        'Generic Name', 'Product Title', 'Price', 'Overall Rating',
#        'Rating Count', 'Review Count', 'Bought L Month', 'Product Link',
#        'Customer Say', 'Insight', 'Individual Rating', 'Review Title',
#        'Review Date', 'Product Description', 'Verified Purchase',
#        'Review Text', 'Helpful Votes', 'Cleaned Review Text', 'llm_raw',
#        'llm_parsed', 'Sentiment', 'Aspect-PainPoint Pairs',
#        'Standardized Aspect-PainPoint Pairs'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['Primary Key', 'Original Aspect-PainPoint', 'Standardized Category',
#        'Standardized Aspect', 'Standardized Pain Point'],
#       dtype='object')

# %%
data.duplicated(subset=['Primary Key']).sum()
# Out:
# 0

# %%
data[data.duplicated(subset=['Primary Key'], keep = False)].sort_values(by=['Primary Key']).head(5)
# Out:
# Empty DataFrame
# Columns: [Primary Key, Original Aspect-PainPoint, Standardized Category, Standardized Aspect, Standardized Pain Point]
# Index: []

# %%
len(data)
# Out:
# 3778

# %%
len(df1)
# Out:
# 3779

# %%
ddf = pd.merge(df1, data, on=['Primary Key'], how='inner')
ddf.head(2)
# Out:
#    Primary Key  Index        ASIN Model Number Manufacturer Name Generic Name  \
# 0            0      6  B0DZDC247V    MW0Y3HN/A             Apple  MacBook Air
# 1            1     12  B0DZDC247V    MW0Y3HN/A             Apple  MacBook Air
#
#                                        Product Title  Price  Overall Rating  \
# 0  Apple 2025 MacBook Air (13-inch, Apple M4 chip...  89990             4.5
# 1  Apple 2025 MacBook Air (13-inch, Apple M4 chip...  89990             4.5
#
#    Rating Count  ...                                Cleaned Review Text  \
# 0            33  ...                       battery life is only 6 hours
# 1            33  ...  i am planning to but this model but i am seein...
#
#                                              llm_raw  \
# 0  Based on the given examples and rules, here's ...
# 1  Based on the review content, here's the output...
#
#                                           llm_parsed Sentiment  \
# 0  {'Sentiment': 'Negative', 'Aspect-PainPoint Pa...  Negative
# 1  {'Sentiment': 'Neutral', 'Aspect-PainPoint Pai...   Neutral
#
#             Aspect-PainPoint Pairs  Standardized Aspect-PainPoint Pairs  \
# 0      Battery - Short backup time          Battery - Short backup time
# 1  Processor - Low speed (0.01mhz)         Processor - Slow performance
#
#          Original Aspect-PainPoint         Standardized Category  \
# 0      Battery - Short backup time   Battery - Short Backup Time
# 1  Processor - Low speed (0.01mhz)  Processor - Slow Performance
#
#   Standardized Aspect  Standardized Pain Point
# 0             Battery        Short Backup Time
# 1           Processor         Slow Performance
#
# [2 rows x 32 columns]

# %%
len(ddf)
# Out:
# 3778

# %%
# ddf.to_csv("6. my_dataset.csv", index=False)
